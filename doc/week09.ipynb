# %% [markdown]
# # Week 9 - 주간학습정리 - Generative AI
#
# ## 깨달은 내용
# * Large Language Model
# * 생성형 이미지 모델

# %% [markdown]
# ## LLM

# %% [markdown]
# ## 생성형 이미지 모델
# * GAN
# * VAE
# * Flow-based models
# * Diffusion Models
